# %%
import numpy as np
import os
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import tensorflow as tf
from models.Resnet50_Unet import *
from models.MyResnet50_Unet import *

# %%
images = np.load("/media/bot/DANE/MED_DATASETS/NARZ_ZAGRO2/FILES/imgs16.npy")[0:500, :, :, :]
labels = np.load("/media/bot/DANE/MED_DATASETS/NARZ_ZAGRO2/FILES/masks16.npy")[0:500, :, :, :]


N = images.shape[0]
W = images.shape[1]
H = images.shape[2]
C = labels.shape[3]
x_train, x_test_valid, y_train, y_test_valid = train_test_split(images, labels, test_size=0.4, random_state=4)
x_valid, x_test, y_valid, y_test = train_test_split(x_test_valid, y_test_valid, test_size=0.5, random_state=4)

print(x_train.shape, y_train.shape)
# Out:
# (300, 512, 512, 1) (300, 512, 512, 5)

# %%
seg_model = Resnet50_Unet(img_shape = (H, W, 1), num_of_class = C,learning_rate = 2e-4, do_drop = True, drop_rate = 0.5)
seg_model.build_model()
seg_model.show_model()
# Out:
# (None, 32, 32, 1024)
# (None, 64, 64, 512)
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 518, 518, 1)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 256, 256, 64) 3200        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 256, 256, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# ...

# %%
history = seg_model.train(x_train, y_train, x_valid, y_valid, epoch = 20, batch_size = 2)
# Out:
# Epoch 1/20
# 150/150 [==============================] - 949s 6s/step - loss: 0.6322 - dice_coef_multilabel: 0.0335 - iou_multilabel: 0.0180 - val_loss: 0.4765 - val_dice_coef_multilabel: 0.0382 - val_iou_multilabel: 0.0205
# /home/bot/.local/lib/python3.8/site-packages/tensorflow/python/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# INFO:tensorflow:Assets written to: saved_models/Resnet50_UNet_model/assets
# Epoch 2/20
# 150/150 [==============================] - 955s 6s/step - loss: 0.2774 - dice_coef_multilabel: 0.0606 - iou_multilabel: 0.0342 - val_loss: 0.1436 - val_dice_coef_multilabel: 0.0317 - val_iou_multilabel: 0.0167
# Epoch 3/20
# ...
