# %%
import numpy as np
import os
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import tensorflow as tf
from models.UNet import *

# %%
images = np.load("/media/bot/DANE/MED_DATASETS/NARZ_ZAGRO2/FILES/imgs16.npy")[0:200, :, :, :]
labels = np.load("/media/bot/DANE/MED_DATASETS/NARZ_ZAGRO2/FILES/masks16.npy")[0:200, :, :, :]


N = images.shape[0]
W = images.shape[1]
H = images.shape[2]
C = labels.shape[3]

# %%
x_train, x_test_valid, y_train, y_test_valid = train_test_split(images, labels, test_size=0.4, random_state=4)
x_valid, x_test, y_valid, y_test = train_test_split(x_test_valid, y_test_valid, test_size=0.5, random_state=4)

print(x_train.shape, y_train.shape)
# Out:
# (120, 512, 512, 1) (120, 512, 512, 5)

# %%
seg_model = UNet(img_shape = (H, W, 1), num_of_class = C,learning_rate = 2e-4, do_drop = True, drop_rate = 0.5)
seg_model.build_model_VGG13()
seg_model.show_model()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 512, 512, 64) 640         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 512, 512, 64) 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 256, 256, 64) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 128 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 128 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 256 295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 256 590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 512)  2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 512)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 1024) 9438208     conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 64, 64, 512)  4719104     conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 64, 64, 1024) 0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 64, 64, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 64, 512)  2359808     conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 128, 128, 256 1179904     conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 128, 128, 512 0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 128, 128, 256 1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 128, 128, 256 590080      conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 256, 256, 128 295040      conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256, 256, 256 0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 256, 256, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 256, 256, 128 147584      conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 512, 512, 64) 73792       conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 512, 512, 128 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 512, 512, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 512, 512, 64) 36928       conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 512, 512, 5)  325         conv2d_17[0][0]
# ==================================================================================================
# Total params: 34,512,453
# Trainable params: 34,512,453
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
history = seg_model.train(x_train, y_train, x_valid, y_valid, epoch = 20, batch_size = 2)
# Out:
# Epoch 1/20
# 60/60 [==============================] - 806s 13s/step - loss: 3.1619 - dice_coef_multilabel: 0.0400 - iou_multilabel: 0.0221 - val_loss: 0.7184 - val_dice_coef_multilabel: 0.0941 - val_iou_multilabel: 0.0557
# INFO:tensorflow:Assets written to: saved_models/UNet_model/assets
# Epoch 2/20
# 60/60 [==============================] - 812s 14s/step - loss: 0.6521 - dice_coef_multilabel: 0.1271 - iou_multilabel: 0.0788 - val_loss: 0.4102 - val_dice_coef_multilabel: 0.1162 - val_iou_multilabel: 0.0709
# INFO:tensorflow:Assets written to: saved_models/UNet_model/assets
# Epoch 3/20
# 60/60 [==============================] - 862s 14s/step - loss: 0.4537 - dice_coef_multilabel: 0.1355 - iou_multilabel: 0.0856 - val_loss: 0.7589 - val_dice_coef_multilabel: 0.1446 - val_iou_multilabel: 0.0931
# INFO:tensorflow:Assets written to: saved_models/UNet_model/assets
# Epoch 4/20
# 60/60 [==============================] - 849s 14s/step - loss: 0.4750 - dice_coef_multilabel: 0.1208 - iou_multilabel: 0.0754 - val_loss: 0.2673 - val_dice_coef_multilabel: 0.1283 - val_iou_multilabel: 0.0804
# Epoch 5/20
# 60/60 [==============================] - 796s 13s/step - loss: 0.2828 - dice_coef_multilabel: 0.1371 - iou_multilabel: 0.0874 - val_loss: 0.2536 - val_dice_coef_multilabel: 0.1407 - val_iou_multilabel: 0.0910
# Epoch 6/20
# 60/60 [==============================] - 752s 13s/step - loss: 0.2699 - dice_coef_multilabel: 0.1269 - iou_multilabel: 0.0810 - val_loss: 0.2794 - val_dice_coef_multilabel: 0.1165 - val_iou_multilabel: 0.0708
# Epoch 7/20
# 60/60 [==============================] - 798s 13s/step - loss: 0.2122 - dice_coef_multilabel: 0.1561 - iou_multilabel: 0.1007 - val_loss: 0.2366 - val_dice_coef_multilabel: 0.1636 - val_iou_multilabel: 0.1095
# INFO:tensorflow:Assets written to: saved_models/UNet_model/assets
# Epoch 8/20
# 60/60 [==============================] - 758s 13s/step - loss: 0.2716 - dice_coef_multilabel: 0.1465 - iou_multilabel: 0.0938 - val_loss: 0.1534 - val_dice_coef_multilabel: 0.1589 - val_iou_multilabel: 0.1017
# Epoch 9/20
# 60/60 [==============================] - 743s 12s/step - loss: 0.1538 - dice_coef_multilabel: 0.1615 - iou_multilabel: 0.1042 - val_loss: 0.1285 - val_dice_coef_multilabel: 0.1784 - val_iou_multilabel: 0.1165
# INFO:tensorflow:Assets written to: saved_models/UNet_model/assets
# Epoch 10/20
# 60/60 [==============================] - 743s 12s/step - loss: 0.1431 - dice_coef_multilabel: 0.1764 - iou_multilabel: 0.1160 - val_loss: 0.1133 - val_dice_coef_multilabel: 0.1872 - val_iou_multilabel: 0.1255
# INFO:tensorflow:Assets written to: saved_models/UNet_model/assets
# Epoch 11/20
# 60/60 [==============================] - 744s 12s/step - loss: 0.1157 - dice_coef_multilabel: 0.2184 - iou_multilabel: 0.1604 - val_loss: 0.1240 - val_dice_coef_multilabel: 0.2453 - val_iou_multilabel: 0.1976
# INFO:tensorflow:Assets written to: saved_models/UNet_model/assets
# Epoch 12/20
# 60/60 [==============================] - 742s 12s/step - loss: 0.1419 - dice_coef_multilabel: 0.1693 - iou_multilabel: 0.1174 - val_loss: 0.0768 - val_dice_coef_multilabel: 0.2248 - val_iou_multilabel: 0.1680
# Epoch 13/20
# 60/60 [==============================] - 742s 12s/step - loss: 0.0847 - dice_coef_multilabel: 0.2541 - iou_multilabel: 0.1993 - val_loss: 0.0863 - val_dice_coef_multilabel: 0.2589 - val_iou_multilabel: 0.2167
# INFO:tensorflow:Assets written to: saved_models/UNet_model/assets
# Epoch 14/20
# 60/60 [==============================] - 743s 12s/step - loss: 0.0744 - dice_coef_multilabel: 0.3048 - iou_multilabel: 0.2603 - val_loss: 0.0649 - val_dice_coef_multilabel: 0.3258 - val_iou_multilabel: 0.2817
# INFO:tensorflow:Assets written to: saved_models/UNet_model/assets
# Epoch 15/20
# 60/60 [==============================] - 743s 12s/step - loss: 0.0623 - dice_coef_multilabel: 0.3055 - iou_multilabel: 0.2650 - val_loss: 0.0411 - val_dice_coef_multilabel: 0.3100 - val_iou_multilabel: 0.2728
# Epoch 16/20
# 60/60 [==============================] - 742s 12s/step - loss: 0.0369 - dice_coef_multilabel: 0.3375 - iou_multilabel: 0.3010 - val_loss: 0.0475 - val_dice_coef_multilabel: 0.3629 - val_iou_multilabel: 0.3249
# INFO:tensorflow:Assets written to: saved_models/UNet_model/assets
# Epoch 17/20
# 60/60 [==============================] - 742s 12s/step - loss: 0.0396 - dice_coef_multilabel: 0.3423 - iou_multilabel: 0.3100 - val_loss: 0.0311 - val_dice_coef_multilabel: 0.3635 - val_iou_multilabel: 0.3243
# INFO:tensorflow:Assets written to: saved_models/UNet_model/assets
# Epoch 18/20
# 60/60 [==============================] - 742s 12s/step - loss: 0.0486 - dice_coef_multilabel: 0.3300 - iou_multilabel: 0.3001 - val_loss: 0.0387 - val_dice_coef_multilabel: 0.3352 - val_iou_multilabel: 0.3074
# Epoch 19/20
# 60/60 [==============================] - 742s 12s/step - loss: 0.0285 - dice_coef_multilabel: 0.3755 - iou_multilabel: 0.3397 - val_loss: 0.0261 - val_dice_coef_multilabel: 0.3846 - val_iou_multilabel: 0.3407
# INFO:tensorflow:Assets written to: saved_models/UNet_model/assets
# Epoch 20/20
# 60/60 [==============================] - 742s 12s/step - loss: 0.0238 - dice_coef_multilabel: 0.3839 - iou_multilabel: 0.3470 - val_loss: 0.0219 - val_dice_coef_multilabel: 0.3623 - val_iou_multilabel: 0.3273

# %%
plot_dice(history)

# %%
plot_loss(history)

# %%
preds = loaded_model.predict(x_test)

# %%
print("TEST DICE_COEF: ", dice_coef_multilabel(y_test.astype('float32'), preds).numpy())
print("TEST IoU: ", iou_multilabel(y_test.astype('float32'), preds, 5).numpy())
# Out:
# TEST DICE_COEF:  0.45521498
# TEST IoU:  0.4068083

# %%
show_imgs(10, x_test[10:30], y_test[10:30], preds[10:30])

# %%
#LOADING DATA FOR NEXT TRAINING
images = np.load("/media/bot/DANE/MED_DATASETS/NARZ_ZAGRO2/FILES/imgs16.npy")[200:400, :, :, :]
labels = np.load("/media/bot/DANE/MED_DATASETS/NARZ_ZAGRO2/FILES/masks16.npy")[200:400, :, :, :]

# %%
x_train, x_test_valid, y_train, y_test_valid = train_test_split(images, labels, test_size=0.4, random_state=4)
x_valid, x_test, y_valid, y_test = train_test_split(x_test_valid, y_test_valid, test_size=0.5, random_state=4)


N = images.shape[0]
W = images.shape[1]
H = images.shape[2]
C = labels.shape[3]

# %%
loaded_model = tf.keras.models.load_model('saved_models/UNet_model', custom_objects={"dice_coef_multilabel": dice_coef_multilabel, "iou_multilabel": iou_multilabel})

# %%
seg_model2 = UNet(img_shape = (H, W, 1), num_of_class = C, loaded_model = loaded_model, path = "saved_models/UNet_model_run_2", learning_rate = 2e-4, do_drop = True, drop_rate = 0.5)
seg_model2.build_model_VGG13()

# %%
history = seg_model2.train(x_train, y_train, x_valid, y_valid, epoch = 20, batch_size = 2)
# Out:
# Epoch 1/20
# 60/60 [==============================] - 866s 14s/step - loss: 0.2193 - dice_coef_multilabel: 0.0843 - iou_multilabel: 0.0543 - val_loss: 0.0899 - val_dice_coef_multilabel: 0.1200 - val_iou_multilabel: 0.0794
# INFO:tensorflow:Assets written to: saved_models/UNet_model_run_2/assets
# Epoch 2/20
# 60/60 [==============================] - 892s 15s/step - loss: 0.0562 - dice_coef_multilabel: 0.2219 - iou_multilabel: 0.1830 - val_loss: 0.0530 - val_dice_coef_multilabel: 0.2577 - val_iou_multilabel: 0.2293
# INFO:tensorflow:Assets written to: saved_models/UNet_model_run_2/assets
# Epoch 3/20
# 60/60 [==============================] - 979s 16s/step - loss: 0.0416 - dice_coef_multilabel: 0.2658 - iou_multilabel: 0.2364 - val_loss: 0.0286 - val_dice_coef_multilabel: 0.2718 - val_iou_multilabel: 0.2467
# INFO:tensorflow:Assets written to: saved_models/UNet_model_run_2/assets
# Epoch 4/20
# 60/60 [==============================] - 1041s 17s/step - loss: 0.0277 - dice_coef_multilabel: 0.2895 - iou_multilabel: 0.2639 - val_loss: 0.0239 - val_dice_coef_multilabel: 0.2801 - val_iou_multilabel: 0.2495
# INFO:tensorflow:Assets written to: saved_models/UNet_model_run_2/assets
# Epoch 5/20
# 60/60 [==============================] - 933s 16s/step - loss: 0.0217 - dice_coef_multilabel: 0.2907 - iou_multilabel: 0.2686 - val_loss: 0.0242 - val_dice_coef_multilabel: 0.2809 - val_iou_multilabel: 0.2566
# INFO:tensorflow:Assets written to: saved_models/UNet_model_run_2/assets
# Epoch 6/20
# 60/60 [==============================] - 961s 16s/step - loss: 0.0207 - dice_coef_multilabel: 0.3021 - iou_multilabel: 0.2779 - val_loss: 0.0164 - val_dice_coef_multilabel: 0.3072 - val_iou_multilabel: 0.2740
# INFO:tensorflow:Assets written to: saved_models/UNet_model_run_2/assets
# Epoch 7/20
# 60/60 [==============================] - 925s 15s/step - loss: 0.0166 - dice_coef_multilabel: 0.3141 - iou_multilabel: 0.2852 - val_loss: 0.0200 - val_dice_coef_multilabel: 0.3007 - val_iou_multilabel: 0.2772
# Epoch 8/20
# 60/60 [==============================] - 869s 15s/step - loss: 0.0182 - dice_coef_multilabel: 0.3278 - iou_multilabel: 0.2998 - val_loss: 0.0174 - val_dice_coef_multilabel: 0.3128 - val_iou_multilabel: 0.2738
# INFO:tensorflow:Assets written to: saved_models/UNet_model_run_2/assets
# Epoch 9/20
# 60/60 [==============================] - 810s 14s/step - loss: 0.0186 - dice_coef_multilabel: 0.3139 - iou_multilabel: 0.2826 - val_loss: 0.0115 - val_dice_coef_multilabel: 0.3220 - val_iou_multilabel: 0.2873
# INFO:tensorflow:Assets written to: saved_models/UNet_model_run_2/assets
# Epoch 10/20
# 60/60 [==============================] - 807s 13s/step - loss: 0.0117 - dice_coef_multilabel: 0.3586 - iou_multilabel: 0.3238 - val_loss: 0.0109 - val_dice_coef_multilabel: 0.3452 - val_iou_multilabel: 0.3046
# INFO:tensorflow:Assets written to: saved_models/UNet_model_run_2/assets
# Epoch 11/20
# 60/60 [==============================] - 809s 13s/step - loss: 0.0108 - dice_coef_multilabel: 0.3756 - iou_multilabel: 0.3383 - val_loss: 0.0106 - val_dice_coef_multilabel: 0.3348 - val_iou_multilabel: 0.3013
# Epoch 12/20
# 60/60 [==============================] - 811s 14s/step - loss: 0.0223 - dice_coef_multilabel: 0.3388 - iou_multilabel: 0.3030 - val_loss: 0.0161 - val_dice_coef_multilabel: 0.3228 - val_iou_multilabel: 0.2894
# Epoch 13/20
# 60/60 [==============================] - 1004s 17s/step - loss: 0.0132 - dice_coef_multilabel: 0.3485 - iou_multilabel: 0.3192 - val_loss: 0.0124 - val_dice_coef_multilabel: 0.3231 - val_iou_multilabel: 0.2957
# Epoch 14/20
# 60/60 [==============================] - 917s 15s/step - loss: 0.0078 - dice_coef_multilabel: 0.3837 - iou_multilabel: 0.3444 - val_loss: 0.0060 - val_dice_coef_multilabel: 0.3845 - val_iou_multilabel: 0.3401
# INFO:tensorflow:Assets written to: saved_models/UNet_model_run_2/assets
# Epoch 15/20
# 60/60 [==============================] - 978s 16s/step - loss: 0.0057 - dice_coef_multilabel: 0.3813 - iou_multilabel: 0.3428 - val_loss: 0.0050 - val_dice_coef_multilabel: 0.4038 - val_iou_multilabel: 0.3555
# INFO:tensorflow:Assets written to: saved_models/UNet_model_run_2/assets
# Epoch 16/20
# 60/60 [==============================] - 989s 17s/step - loss: 0.0043 - dice_coef_multilabel: 0.4392 - iou_multilabel: 0.3911 - val_loss: 0.0038 - val_dice_coef_multilabel: 0.4380 - val_iou_multilabel: 0.3838
# INFO:tensorflow:Assets written to: saved_models/UNet_model_run_2/assets
# Epoch 17/20
# 60/60 [==============================] - 884s 15s/step - loss: 0.0038 - dice_coef_multilabel: 0.4451 - iou_multilabel: 0.3946 - val_loss: 0.0072 - val_dice_coef_multilabel: 0.3846 - val_iou_multilabel: 0.3385
# Epoch 18/20
# 60/60 [==============================] - 793s 13s/step - loss: 0.0045 - dice_coef_multilabel: 0.4608 - iou_multilabel: 0.4083 - val_loss: 0.0035 - val_dice_coef_multilabel: 0.4534 - val_iou_multilabel: 0.3952
# INFO:tensorflow:Assets written to: saved_models/UNet_model_run_2/assets
# Epoch 19/20
# 60/60 [==============================] - 997s 17s/step - loss: 0.0030 - dice_coef_multilabel: 0.5133 - iou_multilabel: 0.4501 - val_loss: 0.0027 - val_dice_coef_multilabel: 0.4864 - val_iou_multilabel: 0.4234
# INFO:tensorflow:Assets written to: saved_models/UNet_model_run_2/assets
# Epoch 20/20
# 60/60 [==============================] - 883s 15s/step - loss: 0.0029 - dice_coef_multilabel: 0.4606 - iou_multilabel: 0.4037 - val_loss: 0.0029 - val_dice_coef_multilabel: 0.4873 - val_iou_multilabel: 0.4243
# INFO:tensorflow:Assets written to: saved_models/UNet_model_run_2/assets

# %%
plot_dice(history)

# %%
plot_loss(history)

# %%
preds = seg_model2.predict(x_test)
print("TEST DICE_COEF: ", dice_coef_multilabel(y_test.astype('float32'), preds).numpy())
print("TEST IoU: ", iou_multilabel(y_test.astype('float32'), preds, 5).numpy())
# Out:
# TEST DICE_COEF:  0.7119273
# TEST IoU:  0.6290037

# %%
show_num = 20
show_imgs(10, x_test[10:30], y_test[10:30], preds[10:30])
